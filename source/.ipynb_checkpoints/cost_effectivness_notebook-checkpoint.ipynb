# %%
from psa import Strategy, Disease, Psa, Icer
from load_data import data_loader

# %% [markdown]
# # Toy data

# %%
# Disease Definitions
d1 = Disease(name='disease1',carrier_rate=0.01,life_expectancy=80,cost=10000)
d2 = Disease(name='disease2',carrier_rate=0.02,life_expectancy=60,cost=20000)
d3 = Disease(name='disease3',carrier_rate=0.005,life_expectancy=40,cost=100000)
disease_dict_fake = {'disease1':d1,'disease2':d2,'disease3':d3}


# Strategies Definition
s0 = Strategy('No testing',disease_list=[],testing_cost=0,disease_dict=disease_dict_fake)
s1 = Strategy('Limited screening',disease_list=['disease2'],testing_cost=1000,disease_dict=disease_dict_fake)
s2 = Strategy('Full screening',disease_list=['disease1','disease2','disease3'],testing_cost=1200,disease_dict=disease_dict_fake)

strategy_dict_fake = {'s0':s0,'s1':s1,'s2':s2}

# %%
s0.assess_strategy(disease_space=['disease1','disease2','disease3'])
# Out:
# {'p_affected_total': 0.00013125,
#  'life_exp': 82.99735624999998,
#  'total_cost': 2.875}

# %%
icer1 = Icer(s2,s1)
icer1.compute_icer()
display(icer1.icer)
display(icer1.delta_years)
display(icer1.delta_costs)
# Out:
# 785331.5958672068
# 0.0002542058750094611
# 199.6359054999998

# %%
icer1.univariate_sensitivity('testing_cost1',0,12000,50)
icer1.plot_sensitivity()

# %%
psa = Psa(s2,s0)
psa.run_mc(disease_space=['disease1','disease2','disease3'],
    intervention_cost_lb=2000, intervention_cost_ub=3000,
       testing_cost1_lb=1000, testing_cost1_ub=1300,
        testing_cost2_lb=0, testing_cost2_ub=0,
        eps_cs_lb=0,eps_cs_ub=0.02,
        eps_pgt_lb=0,eps_pgt_ub=0.02,
        rho_notint_lb=0.1,rho_notint_ub=0.4,nsim=10000)

psa.plot_ceac_hist()

# %% [markdown]
# # Load real data

# %%
file_disease = '../data/Dati Input Disease.xlsx'
file_strategies = '../data/Dati Input Strategies.xlsx'
file_costs = '../data/Dati Input Costs.xlsx'

dl = data_loader(file_disease,file_strategies,file_costs=file_costs)

# %%
dl.disease_dict['Beta Thalassemia'].__str__()
# Out:
# 'Beta Thalassemia'

# %%
dl.disease_dict['Beta Thalassemia']
# Out:
# Disease: Beta Thalassemia

# %%
for strategy in dl.strategy_dict.keys():

    display(strategy,
            dl.strategy_dict[strategy].assess_strategy(intervention_cost=19714,eps_cs=0,eps_pgt=0))
# Out:
# 'Strategy A2 (FS)'
# {'p_affected_total': 0.0029220142149523945,
#  'life_exp': 82.9928847976054,
#  'total_cost': 1898.8747568539836}
# 'Strategy C (ACOG)'
# {'p_affected_total': 7.702183673469381e-05,
#  'life_exp': 82.99670646102041,
#  'total_cost': 282.8572439373468}
# 'Strategy D (AMCG)'
# {'p_affected_total': 0.00010593820861677995,
#  'life_exp': 82.99554244614512,
#  'total_cost': 701.3618980300449}
# 'Strategy A1 (MS)'
# {'p_affected_total': 0.0005376596549183127,
#  'life_exp': 82.99540260614512,
#  'total_cost': 888.2995912768089}
# 'No testing'
# {'p_affected_total': 0, 'life_exp': 83, 'total_cost': 0}

# %%
dl.strategy_dict.keys()
# Out:
# dict_keys(['Strategy A2 (FS)', 'Strategy C (ACOG)', 'Strategy D (AMCG)', 'Strategy A1 (MS)', 'No testing'])

# %%
import pandas as pd
df_icer = pd.DataFrame()

for comparison in [('Strategy A1 (MS)','No testing'),
                  ('Strategy A2 (FS)','No testing'),
                  ('Strategy A1 (MS)','Strategy C (ACOG)'),
                  ('Strategy A1 (MS)','Strategy D (AMCG)'),
                  ('Strategy A2 (FS)','Strategy C (ACOG)'),
                  ('Strategy A2 (FS)','Strategy D (AMCG)')]:
    strategy1 = comparison[0]
    strategy2 = comparison[1]

    icer1 = Icer(dl.strategy_dict[strategy1],dl.strategy_dict[strategy2],
                 eps_cs=0,eps_pgt=0,intervention_cost=19714)
    icer1.compute_icer()
    display(icer1.disease_space)
    df_icer = df_icer.append(
        {'strategy1':strategy1,'strategy2':strategy2,
           'icer':icer1.icer,
           'total cost1':icer1.total_cost1,
           'total cost2':icer1.total_cost2,
           'life exp1':icer1.life_exp1,
           'life exp2':icer1.life_exp2,
          'benefit':icer1.life_exp1-icer1.life_exp2},ignore_index=True)
# Out:
# ['Phenylketonuria',
#  'Spinal Muscular Atrophy',
#  'Beta Thalassemia',
#  'Fragile X Syndrome',
#  'Cystic Fibrosis']
# ['Glycogen Storage Disease Type 2',
#  'Fabry Disease',
#  'Long-chain 3-hydroxyacyl-CoA Dehydrogenase Deficiency',
#  'Emery-Dreifuss Muscular Dystrophy',
#  'Metachromatic Leukodystrophy',
#  'Oxalosis or Primary Hyperoxaluria',
#  'Phenylketonuria',
#  'Fragile X Syndrome',
#  'Biotinidase Deficiency',
#  'Medium-chain Acyl-CoA Dehydrogenase Deficiency',
#  'Achondrogenesis Type 1B',
#  'Congenital Disorder of Glycosylation Type 1A',
#  'Methylmalonic Acidaemia with Homocystinuria',
#  'Galactosemia',
#  'Homocystinuria',
#  'Hemolytic Anemia due to G6PD Deficiency',
#  'Spinal Muscular Atrophy',
#  'Beta Thalassemia',
#  'Deafness, Autosomal Recessive 1A',
#  'Smith-Lemli-Opitz Syndrome',
#  'Cystic Fibrosis']
# ['Phenylketonuria',
#  'Spinal Muscular Atrophy',
#  'Beta Thalassemia',
#  'Fragile X Syndrome',
#  'Cystic Fibrosis']
# ['Phenylketonuria',
#  'Spinal Muscular Atrophy',
#  'Beta Thalassemia',
#  'Fragile X Syndrome',
#  'Cystic Fibrosis']
# ['Glycogen Storage Disease Type 2',
#  'Fabry Disease',
#  'Long-chain 3-hydroxyacyl-CoA Dehydrogenase Deficiency',
#  'Emery-Dreifuss Muscular Dystrophy',
#  'Metachromatic Leukodystrophy',
#  'Oxalosis or Primary Hyperoxaluria',
#  'Phenylketonuria',
#  'Fragile X Syndrome',
#  'Biotinidase Deficiency',
#  'Medium-chain Acyl-CoA Dehydrogenase Deficiency',
#  'Achondrogenesis Type 1B',
#  'Congenital Disorder of Glycosylation Type 1A',
#  'Methylmalonic Acidaemia with Homocystinuria',
#  'Galactosemia',
#  'Homocystinuria',
#  'Hemolytic Anemia due to G6PD Deficiency',
#  'Spinal Muscular Atrophy',
#  'Beta Thalassemia',
#  'Deafness, Autosomal Recessive 1A',
#  'Smith-Lemli-Opitz Syndrome',
#  'Cystic Fibrosis']
# ['Glycogen Storage Disease Type 2',
#  'Fabry Disease',
#  'Long-chain 3-hydroxyacyl-CoA Dehydrogenase Deficiency',
#  'Emery-Dreifuss Muscular Dystrophy',
#  'Metachromatic Leukodystrophy',
#  'Oxalosis or Primary Hyperoxaluria',
#  'Phenylketonuria',
#  'Fragile X Syndrome',
#  'Biotinidase Deficiency',
#  'Medium-chain Acyl-CoA Dehydrogenase Deficiency',
#  'Achondrogenesis Type 1B',
#  'Congenital Disorder of Glycosylation Type 1A',
#  'Methylmalonic Acidaemia with Homocystinuria',
#  'Galactosemia',
#  'Homocystinuria',
#  'Hemolytic Anemia due to G6PD Deficiency',
#  'Spinal Muscular Atrophy',
#  'Beta Thalassemia',
#  'Deafness, Autosomal Recessive 1A',
#  'Smith-Lemli-Opitz Syndrome',
#  'Cystic Fibrosis']

# %%
import pandas as pd
df_icer_sensitivity = pd.DataFrame()

# %%
mydict = {'testing_cost':100,'testing_cost':200,'intervention_cost':3}

# %%
[a for a in mydict.items()]
# Out:
# [('testing_cost', 200), ('intervention_cost', 3)]

# %%
import pandas as pd
df_icer_sensitivity = pd.DataFrame()



for comparison in [('Strategy A1 (MS)','No testing'),
                  ('Strategy A2 (FS)','No testing'),
                  ('Strategy A1 (MS)','Strategy C (ACOG)'),
                  ('Strategy A1 (MS)','Strategy D (AMCG)'),
                  ('Strategy A2 (FS)','Strategy C (ACOG)'),
                  ('Strategy A2 (FS)','Strategy D (AMCG)')]:
    strategy1 = comparison[0]
    strategy2 = comparison[1]

    icer1 = Icer(dl.strategy_dict[strategy1],dl.strategy_dict[strategy2],
                 eps_cs=0,eps_pgt=0,intervention_cost=19714)
    icer1.compute_icer()
    display(icer1.disease_space)
    df_icer = df_icer.append(
        {'strategy1':strategy1,'strategy2':strategy2,
           'icer':icer1.icer,
           'total cost1':icer1.total_cost1,
           'total cost2':icer1.total_cost2,
           'life exp1':icer1.life_exp1,
           'life exp2':icer1.life_exp2,
          'benefit':icer1.life_exp1-icer1.life_exp2},ignore_index=True)
# Out:
# ['Phenylketonuria',
#  'Spinal Muscular Atrophy',
#  'Beta Thalassemia',
#  'Fragile X Syndrome',
#  'Cystic Fibrosis']
# ['Glycogen Storage Disease Type 2',
#  'Fabry Disease',
#  'Long-chain 3-hydroxyacyl-CoA Dehydrogenase Deficiency',
#  'Emery-Dreifuss Muscular Dystrophy',
#  'Metachromatic Leukodystrophy',
#  'Oxalosis or Primary Hyperoxaluria',
#  'Phenylketonuria',
#  'Fragile X Syndrome',
#  'Biotinidase Deficiency',
#  'Medium-chain Acyl-CoA Dehydrogenase Deficiency',
#  'Achondrogenesis Type 1B',
#  'Congenital Disorder of Glycosylation Type 1A',
#  'Methylmalonic Acidaemia with Homocystinuria',
#  'Galactosemia',
#  'Homocystinuria',
#  'Hemolytic Anemia due to G6PD Deficiency',
#  'Spinal Muscular Atrophy',
#  'Beta Thalassemia',
#  'Deafness, Autosomal Recessive 1A',
#  'Smith-Lemli-Opitz Syndrome',
#  'Cystic Fibrosis']
# ['Phenylketonuria',
#  'Spinal Muscular Atrophy',
#  'Beta Thalassemia',
#  'Fragile X Syndrome',
#  'Cystic Fibrosis']
# ['Phenylketonuria',
#  'Spinal Muscular Atrophy',
#  'Beta Thalassemia',
#  'Fragile X Syndrome',
#  'Cystic Fibrosis']
# ['Glycogen Storage Disease Type 2',
#  'Fabry Disease',
#  'Long-chain 3-hydroxyacyl-CoA Dehydrogenase Deficiency',
#  'Emery-Dreifuss Muscular Dystrophy',
#  'Metachromatic Leukodystrophy',
#  'Oxalosis or Primary Hyperoxaluria',
#  'Phenylketonuria',
#  'Fragile X Syndrome',
#  'Biotinidase Deficiency',
#  'Medium-chain Acyl-CoA Dehydrogenase Deficiency',
#  'Achondrogenesis Type 1B',
#  'Congenital Disorder of Glycosylation Type 1A',
#  'Methylmalonic Acidaemia with Homocystinuria',
#  'Galactosemia',
#  'Homocystinuria',
#  'Hemolytic Anemia due to G6PD Deficiency',
#  'Spinal Muscular Atrophy',
#  'Beta Thalassemia',
#  'Deafness, Autosomal Recessive 1A',
#  'Smith-Lemli-Opitz Syndrome',
#  'Cystic Fibrosis']
# ['Glycogen Storage Disease Type 2',
#  'Fabry Disease',
#  'Long-chain 3-hydroxyacyl-CoA Dehydrogenase Deficiency',
#  'Emery-Dreifuss Muscular Dystrophy',
#  'Metachromatic Leukodystrophy',
#  'Oxalosis or Primary Hyperoxaluria',
#  'Phenylketonuria',
#  'Fragile X Syndrome',
#  'Biotinidase Deficiency',
#  'Medium-chain Acyl-CoA Dehydrogenase Deficiency',
#  'Achondrogenesis Type 1B',
#  'Congenital Disorder of Glycosylation Type 1A',
#  'Methylmalonic Acidaemia with Homocystinuria',
#  'Galactosemia',
#  'Homocystinuria',
#  'Hemolytic Anemia due to G6PD Deficiency',
#  'Spinal Muscular Atrophy',
#  'Beta Thalassemia',
#  'Deafness, Autosomal Recessive 1A',
#  'Smith-Lemli-Opitz Syndrome',
#  'Cystic Fibrosis']

# %%
df_icer
# Out:
#      benefit           icer  life exp1  life exp2         strategy1  \
# 0   0.015391  -85325.188674  82.995403  82.980011  Strategy A1 (MS)
# 1   0.023820  -76794.228766  82.992885  82.969064  Strategy A2 (FS)
# 2   0.004365 -283459.148004  82.995403  82.991038  Strategy A1 (MS)
# 3   0.000468  278897.461857  82.995403  82.994934  Strategy A1 (MS)
# 4   0.012794 -137040.476234  82.992885  82.980091  Strategy A2 (FS)
# 5   0.008897  -43320.988289  82.992885  82.983987  Strategy A2 (FS)
# 6   0.015391  -85325.188674  82.995403  82.980011  Strategy A1 (MS)
# 7   0.023820  -76794.228766  82.992885  82.969064  Strategy A2 (FS)
# 8   0.004365 -283459.148004  82.995403  82.991038  Strategy A1 (MS)
# 9   0.000468  278897.461857  82.995403  82.994934  Strategy A1 (MS)
# 10  0.012794 -137040.476234  82.992885  82.980091  Strategy A2 (FS)
# 11  0.008897  -43320.988289  82.992885  82.983987  Strategy A2 (FS)
#
#             strategy2  total cost1  total cost2
# 0          No testing   888.299591  2201.563041
# 1          No testing  1898.874757  3728.148626
# 2   Strategy C (ACOG)   888.299591  2125.621269
# 3   Strategy D (AMCG)   888.299591   757.730956
# 4   Strategy C (ACOG)  1898.874757  3652.206854
# 5   Strategy D (AMCG)  1898.874757  2284.316540
# 6          No testing   888.299591  2201.563041
# 7          No testing  1898.874757  3728.148626
# 8   Strategy C (ACOG)   888.299591  2125.621269
# 9   Strategy D (AMCG)   888.299591   757.730956
# 10  Strategy C (ACOG)  1898.874757  3652.206854
# 11  Strategy D (AMCG)  1898.874757  2284.316540

# %%
psa.plot_ceac()
